# %% [markdown]
# <a href="https://colab.research.google.com/github/mehta-aditya13191/Machine-Learning/blob/main/05_Importing_data_from_kaggle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#  loading a dataset to a pandas dataframe
dataset=pd.read_csv('/content/Housing.csv')

# %%
dataset.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %% [markdown]
# API -Application Programming Interface

# %%
#  Installing the kaggle library
# !pip install kaggle

# %% [markdown]
# Upload your Kaggle.json file

# %%
# configuring the path of kaggle.json file
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# Importing the Earthquake Dataset

# %%
# Api to fetch the dataset from 'Kaggle
# !kaggle competitions download -c LANL-Earthquake-Prediction
# Out:
# ...
# 100% 2.27G/2.27G [00:37<00:00, 112MB/s]
# 100% 2.27G/2.27G [00:37<00:00, 65.2MB/s]

# %%
# !unzip LANL-Earthquake-Prediction.zip -d ./LANL_Earthquake_Prediction
# Out:
# Archive:  LANL-Earthquake-Prediction.zip
#   inflating: ./LANL_Earthquake_Prediction/sample_submission.csv
#   inflating: ./LANL_Earthquake_Prediction/test/seg_00030f.csv
#   inflating: ./LANL_Earthquake_Prediction/test/seg_0012b5.csv
#   inflating: ./LANL_Earthquake_Prediction/test/seg_00184e.csv
#   inflating: ./LANL_Earthquake_Prediction/test/seg_003339.csv
#   inflating: ./LANL_Earthquake_Prediction/test/seg_0042cc.csv
#   inflating: ./LANL_Earthquake_Prediction/test/seg_004314.csv
#   inflating: ./LANL_Earthquake_Prediction/test/seg_004cd2.csv
#   inflating: ./LANL_Earthquake_Prediction/test/seg_004ee5.csv
#   inflating: ./LANL_Earthquake_Prediction/test/seg_004f1f.csv
#   inflating: ./LANL_Earthquake_Prediction/test/seg_00648a.csv
#   inflating: ./LANL_Earthquake_Prediction/test/seg_006e4a.csv
#   inflating: ./LANL_Earthquake_Prediction/test/seg_007a37.csv
#   inflating: ./LANL_Earthquake_Prediction/test/seg_00a37e.csv
# ...

# %%
# Extracting the compressed file
from zipfile import ZipFile
dataset='filepath'

with ZipFile(dataset,'r') as zip:
  zip.extractall()
  print('The dataset is extracted')
